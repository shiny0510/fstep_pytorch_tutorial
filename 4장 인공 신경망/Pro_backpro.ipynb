# %% [markdown]
# ![back1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #Propagation
#
# ### - Hidden Layer
# 1. $y_{1}^{1} = X_{1}W_{11}^{1} + X_{2}W_{12}^{1} + X_{3}W_{13}^{1}$
#
# 2. $a_{1}^{1} = sigmoid(y_{1}^{1})$
#
# ---
#
# ### - Output Layer
# 1-1. $y_{1}^{1} = a_{1}^{1}W_{11}^{1} + a_{2}^{1}W_{12}^{1} + a_{3}^{1}W_{13}^{1}$
#
# 1-2. $y_{2}^{2} = a_{1}^{1}W_{11}^{2} + a_{2}^{1}W_{12}^{2} + a_{3}^{1}W_{13}^{2}$
#
#
# 2-1. $a_{1}^{2} = sigmoid(y_{1}^{1})$
#
# 2-2. $a_{2}^{2} = sigmoid(y_{2}^{2})$
#
# ---
#
# $L = \displaystyle\sum_{k=1}^{2}(t_k-a_k^2)^2 $ → (MSE)
#
#
# ---
#
#
# ###- $w_{11}^2$ Update
#
# - Chain rule
#
# $\frac{\mathrm dL}{\mathrm dw_{11}^2} = \frac{\mathrm dL}{\mathrm da_1^2}
# \frac{\mathrm da_1^2}{\mathrm dy_1^2}\frac{\mathrm dy_1^2}{\mathrm dw_{11}^2} $
#
#
# #### 1) $\frac{\mathrm dL}{\mathrm da_1^2}= -2(t_1-a_1^2)$
#
# #### 2) $\frac{\mathrm da_1^2}{\mathrm da_1^2} $ $ =a_1^2(1-a_1^2)$
#
# #### 3) $\frac{\mathrm dy_1^2}{\mathrm dw_{11}^2} = a_1^1 $
#
# #### 4) $w_{11}^2 = w_{11}^2- lr \frac{\mathrm dL}{\mathrm dw_1^2}$

# %% [markdown]
# ![backi2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ###- $w_{11}^1$ Update
#
# - Chain rule
#
# $\frac{\mathrm dL}{\mathrm dw_{11}^1} = \displaystyle\sum_{k=1}^2\frac{\mathrm dL}{\mathrm da_k^2}
# \frac{\mathrm da_k^2}{\mathrm dy_k^2}\frac{\mathrm dy_k^2}{\mathrm da_1^1}\frac{\mathrm da_1^1}{\mathrm dy_1^1}\frac{\mathrm dy_1^1}{\mathrm dw_{11}^1}$
#
#
# #### 4) $w_{11}^1 = w_{11}^1- lr \frac{\mathrm dL}{\mathrm dw_{11}^1}$
